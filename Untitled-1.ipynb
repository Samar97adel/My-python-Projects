# %%
def hello(name,age):
    return f"my name is {name} and my age is {age}"

# %%
hello('samar',29)
# Out:
# 'my name is samar and my age is 29'

# %%
l=[10,20,30,40,50]
double=lambda x: x*2
mm=list(map(double,l))
ff=list(filter(lambda x:x<50,mm))
res=reduce(lambda x,y)
l(res)
# Out:
#   Cell In[31], line 5
#     res=reduce(lambda x,y)
#                          ^
# SyntaxError: invalid syntax
