# %%
def sum_num(x, y):
    z=x+y
    return z

# %%
sum_num(33,66)
# Out:
# 99

# %%
def Hello():
    return 'hello all in python'

# %%
Hello()
# Out:
# 'hello all in python'

# %%
name='Samar'
print(f'hello {name}')
# Out:
# hello Samar

# %%
name='samar'
age=29
gender='Female'
print(f'i am {name}\n i am {age}\n i am {gender}')
# Out:
# i am samar
#  i am 29
#  i am Female

# %%
def hell0(name):
    return f'Hello {name} in Amit'

# %%
 hell0('samar')
# Out:
# 'Hello samar in Amit'
