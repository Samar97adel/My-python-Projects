# %%
name='Samar Adel'
name[0: :2]
# Out:
# 'SmrAe'

# %%
## data structure

# %%
## list & Tuple  & set & dictionary

# %%
l2=[11,33,44,55,'Samar',True,33.55,'python']
l2.append(15)
l2
# Out:
# [11, 33, 44, 55, 'Samar', True, 33.55, 'python', 15]

# %%
l2.extend([77,888,99,'Sayed'])
l2
# Out:
# [11, 33, 44, 55, 'Samar', True, 33.55, 'python', 15, 77, 888, 99, 'Sayed']

# %%
l2.insert(5,'Adel')
l2
# Out:
# [11,
#  33,
#  44,
#  55,
#  'Samar',
#  'Adel',
#  True,
#  33.55,
#  'python',
#  15,
#  77,
#  888,
#  99,
#  'Sayed']

# %%
l2.remove('python')
l2
# Out:
# [11, 33, 44, 55, 'Samar', 'Adel', True, 33.55, 15, 77, 888, 99, 'Sayed']

# %%
l2.pop(5)
# Out:
# 'Adel'

# %%
l3=[2,6,5,3,7,8,54,89]
l3.sort()
l3
# Out:
# [2, 3, 5, 6, 7, 8, 54, 89]

# %%
l3.sort(reverse=True)
l3
# Out:
# [89, 54, 8, 7, 6, 5, 3, 2]

# %%
l4=['d','s','r','l','h','v']
l4.reverse()
l4
# Out:
# ['v', 'h', 'l', 'r', 's', 'd']

# %%
l4.sort()
l4
# Out:
# ['d', 'h', 'l', 'r', 's', 'v']

# %%
l4.sort(reverse=True)
l4
# Out:
# ['v', 's', 'r', 'l', 'h', 'd']

# %%
l3.reverse()
l3
# Out:
# [2, 3, 5, 6, 7, 8, 54, 89]

# %%
s={15,33,2,3,44,56,76,444,33,8}
s.add(800)
s
# Out:
# {2, 3, 8, 15, 33, 44, 56, 76, 444, 800}

# %%
s.remove(33)
s
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[427], line 1
# ----> 1 s.remove(33)
#       2 s
#
# KeyError: 33
